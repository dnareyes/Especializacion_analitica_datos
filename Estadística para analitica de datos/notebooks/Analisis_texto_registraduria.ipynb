# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
import pandas as pd

# %%
# Load your dataset
df = pd.read_excel('C:\\Users\\Diego Reyes\\Documents\\Code & Courses\\Especializacion_analitica_datos\\Gestion y Conocimiento de  Negocio\\Registraduria\\registraduria_database.xlsx', sheet_name='fact_viaticos')

texto = df['commission_purpose_raw'].tolist()
